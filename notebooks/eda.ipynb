# %%
# Check for missing values
print("Missing Values:")
print(df.isnull().sum())

# Check for duplicates
print(f"\nDuplicate rows: {df.duplicated().sum()}")

# Check data types
print("\nData Types:")
print(df.dtypes)

# %% [markdown]
# ## 4. Quality Checks

# %%
# Plot category distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

df['category'].value_counts().plot(kind='bar', ax=axes[0])
axes[0].set_title('Ticket Category Distribution')
axes[0].set_ylabel('Count')

df['priority'].value_counts().plot(kind='pie', ax=axes[1], autopct='%1.1f%%')
axes[1].set_title('Priority Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Category Distribution

# %%
# Get basic statistics
print("Data Info:")
print(df.info())
print("\nData Statistics:")
print(df.describe())

# %% [markdown]
# ## 2. Data Overview

# %%
# Load support ticket data
# df = pd.read_csv('data/raw/tickets.csv')
# For now, create sample data
df = pd.DataFrame({
    'ticket_id': [f'TICK-{i}' for i in range(1, 101)],
    'title': ['Login Issue', 'Payment Error', 'Shipping Delay'] * 33 + ['Login Issue'],
    'description': ['Cannot access account'] * 100,
    'category': ['Account', 'Billing', 'Shipping'] * 33 + ['Account'],
    'priority': np.random.choice(['Low', 'Medium', 'High'], 100),
    'status': np.random.choice(['Open', 'In Progress', 'Closed'], 100),
})

print(f"Dataset shape: {df.shape}")
df.head()

# %% [markdown]
# ## 1. Load Data

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visualization
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# %% [markdown]
# # Exploratory Data Analysis: Support Tickets
#
# This notebook performs exploratory data analysis on support ticket data, including data overview, distributions, and quality checks.
